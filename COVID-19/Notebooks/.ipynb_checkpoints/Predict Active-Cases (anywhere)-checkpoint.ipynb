# %% [markdown]
# <center><h1> <font color="green"><u>Active-Case Predictions ~ 19-nCoV</u></font> </h1></center>

# %% [markdown]
# <center><h3> <font color="#cc0000"><u>Active Cases(%) out of Confirmed</u></font> </h3></center>

# %% [markdown]
# <h3> <font color="purple"><u>This section includes:</u></font> </h3>

# %% [markdown]
# > * Data Filtering <br />
# > * Training & Testing datasets <br />
# > * Prediction <br />
# > * Visualization (Scatter Plots) <br />

# %% [markdown]
# <br />

# %% [markdown]
# ## Creating Datasets

# %%
# setting the working directory
setwd("~/Documents/A-tracking-of-2019-nCoV/COVID-19/ready_to_use")

# %%
# Loading desired libraries
library(ggplot2)
library(stringr)

# %% [markdown]
# <hr />

# %%
# includes data of all the countries
all = read.csv('COVID-19/Mixed/countryWise_bulk_summary.csv')

# includes data of four majour location
four = read.csv('COVID-19/FOUR/Four_dataset_locationWise.csv')

# %%
# extracting the desired dataset
extractDatases <- function(region){
    if(region %in% c("Hubei", "World", "Diamond Princess")) {
    temp = four[which(str_detect(four$Location, region)),]
    row.names(temp) <- NULL
} else {
    temp = all[which(str_detect(all$Country, region)),]
    row.names(temp) <- NULL
}

return(temp)
}

# %%
# country list
countries = matrix(levels(as.factor(all$Country)))
#head(countries, 10)

# Four majour locations
locations = matrix(levels(as.factor(four$Location)))
#locations

# %% [markdown]
# <br />
# ### Choosing desired Country/Region

# %%
# country i.e. to be used throughout the analysis
 rName = "China" # without hubei

# some other possible values of rName:
# 'World', 'Hubei', 'Diamond Cruise', 'Italy', 'Japan'.....etc

# %% [markdown]
# <hr />

# %%
# filtering out desired country/location 
region1 = extractDatases(rName)

# joining Hubei for complete data of china
region2 = extractDatases("Hubei")

region = cbind(region1[,1:3], region1[,4:8]+region2[,4:8])
colnames(region) <- colnames(region1)

tail(region)
# Out:
#    Country Day Date       Confirmed Deaths Recovered Active.Cases Closed.Cases
# 54 China   54  15-03-2020 81003     3203   67017     10783        70220
# 55 China   55  16-03-2020 81033     3217   67910      9906        71127
# 56 China   56  17-03-2020 81058     3230   68798      9030        72028
# 57 China   57  18-03-2020 81103     3241   69755      8107        72996
# 58 China   58  19-03-2020 81157     3249   70535      7373        73784
# 59 China   59  20-03-2020 81251     3253   71266      6732        74519

# %% [markdown]
# <hr />

# %%
region=region[,c(2, 4:8)]
head(region, 10)
# Out:
#    Day Confirmed Deaths Recovered Active.Cases Closed.Cases
# 1   1   548       17     28        503          45
# 2   2   643       18     30        595          48
# 3   3   920       26     36        858          62
# 4   4  1406       42     39       1325          81
# 5   5  2075       56     49       1970         105
# 6   6  2877       82     58       2737         140
# 7   7  5509      131    101       5277         232
# 8   8  6087      133    120       5834         253
# 9   9  8141      171    135       7835         306
# 10 10  9802      213    214       9375         427

# %%
# calculate the percent (using Confirmed cases as total)
percent <- function(dfName){
    get(dfName) -> df
    part <- NULL
    
    for(i in 1:nrow(df)) {
        val = df[i,"Active.Cases"]
        Total = df[i,"Confirmed"]
        
        
        if(i == 1)
            if(val==0)
                part = 0
            else
                part = as.numeric((val*100)/Total)
        else
            if(val==0)
                part = c(part, 0)
            else
                part <- c(part, as.numeric((val*100)/Total))
    }
        
    return(part)
}

# %% [markdown]
# <hr />

# %%
# CASES -> percentage
region$'percent_active' = percent("region")     # Active cases, out of every 100 Confirmed cases
region$'percent_closed' = 100-percent("region") # Closed cases, out of every 100 Confirmed cases

# %%
head(region)
# Out:
#   Day Confirmed Deaths Recovered Active.Cases Closed.Cases percent_active
# 1 1    548      17     28         503          45          91.78832
# 2 2    643      18     30         595          48          92.53499
# 3 3    920      26     36         858          62          93.26087
# 4 4   1406      42     39        1325          81          94.23898
# 5 5   2075      56     49        1970         105          94.93976
# 6 6   2877      82     58        2737         140          95.13382
#   percent_closed
# 1 8.211679
# 2 7.465008
# 3 6.739130
# 4 5.761024
# 5 5.060241
# 6 4.866180

# %% [markdown]
# <br />* Dataset is ready

# %% [markdown]
# <hr /><br />

# %% [markdown]
# ### Understanding the plot

# %%
# Day vs %Closed Cases
region.scatter.plot <- ggplot(region, aes(x = region$Day, y = region$percent_active)) +
                        geom_point()
region.scatter.plot
# Out:
# plot without title

# %%
tail(region)
# Out:
#    Day Confirmed Deaths Recovered Active.Cases Closed.Cases percent_active
# 54 54  81003     3203   67017     10783        70220        13.311853
# 55 55  81033     3217   67910      9906        71127        12.224649
# 56 56  81058     3230   68798      9030        72028        11.140171
# 57 57  81103     3241   69755      8107        72996         9.995931
# 58 58  81157     3249   70535      7373        73784         9.084860
# 59 59  81251     3253   71266      6732        74519         8.285436
#    percent_closed
# 54 86.68815
# 55 87.77535
# 56 88.85983
# 57 90.00407
# 58 90.91514
# 59 91.71456

# %% [markdown]
# <br /><hr /><br />

# %% [markdown]
# ## Data-Analysis <br />

# %%
# loading plotting/machine learning
library(tidyverse)
library(caret)
library(mlbench)
library(kernlab)
library(rpart)

# setting the theme
theme_set(theme_classic())

# %%
set.seed(20) # generages same set of random sample every time

training.samples <- region$Day %>%
  createDataPartition(p = 0.8, list = FALSE)

train.data  <- region[training.samples, ]
test.data <- region[-training.samples, ]

# %%
tail(train.data, 3)
head(test.data, 3)
# Out:
#    Day Confirmed Deaths Recovered Active.Cases Closed.Cases percent_active
# 57 57  81103     3241   69755     8107         72996        9.995931
# 58 58  81157     3249   70535     7373         73784        9.084860
# 59 59  81251     3253   71266     6732         74519        8.285436
#    percent_closed
# 57 90.00407
# 58 90.91514
# 59 91.71456
#    Day Confirmed Deaths Recovered Active.Cases Closed.Cases percent_active
# 4   4   1406      42      39       1325          81         94.23898
# 13 13  19716     425     615      18676        1040         94.72510
# 15 15  27440     563    1115      25762        1678         93.88484
#    percent_closed
# 4  5.761024
# 13 5.274904
# 15 6.115160

# %%
ggplot(train.data, aes(Day, percent_active) ) +
  geom_point() +
  stat_smooth()
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %% [markdown]
# <br /><hr /><br />

# %% [markdown]
# ## Regrassion

# %% [markdown]
# ### 1. Linear regression

# %%
# building linear model
fit.lm = lm(Day ~ percent_active, data = train.data)
#summary(fit.lm)

# %%
# Predicting
predictions <- fit.lm %>% predict(train.data)

# %%
# Model performance
data.frame(
  RMSE = RMSE(predictions, train.data$Day),
  R2 = R2(predictions, train.data$Day)
)
# Out:
#   RMSE     R2
# 1 4.899713 0.9180098

# %% [markdown]
# <br />

# %%
trainer <- ggplot(train.data, aes(Day, percent_active) ) +
              geom_point() +
              stat_smooth(method = lm, formula = y ~ x) +   # linear function
  
              # decoration
              labs( x = "Days", y = "Active Cases (%)", title = paste("\nTraining plot", rName, sep = " - ") ) +
              theme( plot.title = element_text(size = 20, face = "bold")) 
trainer
# Out:
# plot without title

# %%
tester <- ggplot(test.data, aes(Day, percent_active) ) +
              geom_point() +
              stat_smooth(method = lm, formula = y ~ x) +   # linear function
  
              # decoration
              labs( x = "Days", y = "Active Cases (%)", title = paste("\nTesting plot", rName, sep = " - ") ) +
              theme( plot.title = element_text(size = 20, face = "bold")) 
tester
# Out:
# plot without title

# %% [markdown]
# <br />

# %%
trained = cbind( # Prediction for training data
            train.data[,c("Day", "percent_active")],
            Pridicted_percent_active = predict(fit.lm, train.data)
          )

tested = cbind(  # Prediction for tested data
            test.data[,c("Day", "percent_active")],
            Pridicted_percent_active = predict(fit.lm, test.data)
         )


tail(trained, 5)
tail(tested, 5)
# Out:
#    Day percent_active Pridicted_percent_active
# 54 54  13.311853      55.81131
# 56 56  11.140171      56.95117
# 57 57   9.995931      57.55175
# 58 58   9.084860      58.02995
# 59 59   8.285436      58.44955
#    Day percent_active Pridicted_percent_active
# 41 41  40.39133       41.59802
# 42 42  37.20861       43.26854
# 48 48  23.41454       50.50868
# 51 51  18.35986       53.16175
# 55 55  12.22465       56.38196

# %% [markdown]
# <br />

# %% [markdown]
# ### 2. Polynomial regression

# %%
deg = 16  # degree of polynomial

# building polynomial model
model = lm(percent_active ~ poly(Day, deg, raw = TRUE), data = train.data)
#summary(model)

# %%
# predicting
predictions <- model %>% predict(train.data)
# Out:
# Warning message in predict.lm(., train.data):
# “prediction from a rank-deficient fit may be misleading”

# %%
# Model performance
data.frame(
  RMSE = RMSE(predictions, train.data$Day),
  R2 = R2(predictions, train.data$Day)
)
# Out:
#   RMSE     R2
# 1 58.13515 0.9182244

# %% [markdown]
# <br />

# %%
trainer <- ggplot(train.data, aes(Day, percent_active) ) +
              geom_point() +
              stat_smooth(method = lm, formula = y ~ poly(x, deg, raw = TRUE)) +   # polynomial function
  
              # decoration
              labs( x = "Days", y = "Active Cases (%)", title = paste("\nTraining plot", rName, sep = " - ") ) +
              theme( plot.title = element_text(size = 20, face = "bold")) 
trainer
# Out:
# Warning message in predict.lm(model, newdata = data.frame(x = xseq), se.fit = se, :
# “prediction from a rank-deficient fit may be misleading”
# plot without title

# %%
tester <- ggplot(test.data, aes(Day, percent_active) ) +
              geom_point() +
              stat_smooth(method = lm, formula = y ~ poly(x, deg, raw = TRUE)) +   # polynomial function
  
              # decoration
              labs( x = "Days", y = "Active Cases (%)", title = paste("\nTesting plot", rName, sep = " - ") ) +
              theme( plot.title = element_text(size = 20, face = "bold")) 
tester
# Out:
# Warning message in predict.lm(model, newdata = data.frame(x = xseq), se.fit = se, :
# “prediction from a rank-deficient fit may be misleading”
# Warning message in qt((1 - level)/2, df):
# “NaNs produced”
# plot without title

# %% [markdown]
# <br /><br />

# %%
trained = cbind( # Prediction for training data
            train.data[,c("Day", "percent_active")],
            Pridicted_percent_active = predict(model, train.data)
          )

tested = cbind(  # Prediction for tested data
            test.data[,c("Day", "percent_active")],
            Pridicted_percent_active = predict(model, test.data)
         )


tail(trained, 5)
tail(tested, 5)
# Out:
# Warning message in predict.lm(model, train.data):
# “prediction from a rank-deficient fit may be misleading”
# Warning message in predict.lm(model, test.data):
# “prediction from a rank-deficient fit may be misleading”
#    Day percent_active Pridicted_percent_active
# 54 54  13.311853      13.362586
# 56 56  11.140171      11.162432
# 57 57   9.995931      10.128329
# 58 58   9.084860       8.941923
# 59 59   8.285436       8.323115
#    Day percent_active Pridicted_percent_active
# 41 41  40.39133       40.34923
# 42 42  37.20861       37.08377
# 48 48  23.41454       23.58636
# 51 51  18.35986       18.37514
# 55 55  12.22465       12.16514

# %% [markdown]
# <br />
# ### 3. SVMK Regression

# %%
# model
fit.svmk <- ksvm(percent_active~Day, train.data, kernel="rbfdot")
#summary(fit.svmk)

# %%
predictions <- fit.svmk %>% predict(train.data)

# %%
# Model performance
data.frame(
  RMSE = RMSE(predictions, train.data$Day),
  R2 = R2(predictions, train.data$Day)
)
# Out:
#   RMSE     R2
# 1 56.00677 0.9220422

# %% [markdown]
# <br />

# %%
trained = cbind( # Prediction for training data
            train.data[,c("Day", "percent_active")],
            Pridicted_percent_active = predict(fit.svmk, train.data)
          )

tested = cbind(  # Prediction for tested data
            test.data[,c("Day", "percent_active")],
            Pridicted_percent_active = predict(fit.svmk, test.data)
         )


tail(trained, 5)
tail(tested, 5)
# Out:
#    Day percent_active Pridicted_percent_active
# 54 54  13.311853      15.79572
# 56 56  11.140171      12.65350
# 57 57   9.995931      11.97517
# 58 58   9.084860      12.23955
# 59 59   8.285436      13.62037
#    Day percent_active Pridicted_percent_active
# 41 41  40.39133       43.35515
# 42 42  37.20861       40.22575
# 48 48  23.41454       26.21566
# 51 51  18.35986       21.41494
# 55 55  12.22465       14.02031

# %% [markdown]
# <br />

# %%
trainer <- ggplot(train.data, aes(Day, percent_active) ) +
              geom_point() +
              geom_smooth(data=trained, method="loess", size=0) +
              geom_line(data = trained, aes(Day, Pridicted_percent_active), color="#3366fe", size=1) +   # polynomial function
  
              # decoration
              labs( x = "Days", y = "Active Cases (%)", title = paste("\nTraining plot", rName, sep = " - ") ) +
              theme( plot.title = element_text(size = 20, face = "bold")) 
trainer
# Out:
# plot without title

# %%
tester <- ggplot(test.data, aes(Day, percent_active) ) +
              geom_point() +
              geom_smooth(data=tested, method="loess", size=0) +
              geom_line(data = tested, aes(Day, Pridicted_percent_active), color="#3366fe", size=1) +   # polynomial function
  
              # decoration
              labs( x = "Days", y = "Active Cases (%)", title = paste("\nTesting plot", rName, sep = " - ") ) +
              theme( plot.title = element_text(size = 20, face = "bold")) 
tester
# Out:
# plot without title

# %% [markdown]
# <br />
# ### 4. KNN Regression

# %%
x <- as.matrix(train.data[,1])
y <- as.matrix(train.data[,7])

# fit model
fit.knn <- knnreg(x, y, k=3)
#summary(fit.knn)

# %%
predictions <- fit.knn %>% predict(x)

# %%
data.frame(
  RMSE = RMSE(predictions, x),
  R2 = R2(predictions, x)
)
# Out:
#   RMSE     R2
# 1 58.09279 0.918832

# %% [markdown]
# <br />

# %%
trained = cbind( # Prediction for training data
            train.data[,c("Day", "percent_active")],
            Pridicted_percent_active = predict(fit.knn, as.matrix(train.data[,1]))
          )

tested = cbind(  # Prediction for tested data
            test.data[,c("Day", "percent_active")],
            Pridicted_percent_active = predict(fit.knn, as.matrix(test.data[,1]))
         )


tail(trained, 5)
tail(tested, 5)
# Out:
#    Day percent_active Pridicted_percent_active
# 54 54  13.311853      14.046853
# 56 56  11.140171      10.883204
# 57 57   9.995931      10.073654
# 58 58   9.084860       9.122076
# 59 59   8.285436       9.122076
#    Day percent_active Pridicted_percent_active
# 41 41  40.39133       41.54125
# 42 42  37.20861       36.35828
# 48 48  23.41454       23.55707
# 51 51  18.35986       18.34226
# 55 55  12.22465       12.35503

# %% [markdown]
# <br />

# %%
trainer <- ggplot(train.data, aes(Day, percent_active) ) +
              geom_point() +
              geom_smooth(data=tested, method="loess", size=0) +
              geom_line(data = trained, aes(Day, Pridicted_percent_active), color="#3366fe", size=1) +   # polynomial function
  
              # decoration
              labs( x = "Days", y = "Active Cases (%)", title = paste("\nTraining plot", rName, sep = " - ") ) +
              theme( plot.title = element_text(size = 20, face = "bold")) 
trainer
# Out:
# plot without title

# %%
tester <- ggplot(test.data, aes(Day, percent_active) ) +
              geom_point() +
              geom_smooth(data=tested, method="loess", size=0) +
              geom_line(data = tested, aes(Day, Pridicted_percent_active), color="#3366fe", size=1) +   # polynomial function
  
              # decoration
              labs( x = "Days", y = "Active Cases (%)", title = paste("\nTesting plot", rName, sep = " - ") ) +
              theme( plot.title = element_text(size = 20, face = "bold")) 
tester
# Out:
# plot without title

# %% [markdown]
# <br />

# %% [markdown]
# <br /><hr /><br />

# %% [markdown]
# ## Predictions

# %%
test_Miscellaneous = data.frame(
                        Day = NaN,
                        #Confirmed = NaN,
                        #Active.Cases = NaN,
                        percent_active = 8.2854
                        #percent_closed = NaN
                     )

# %%
test_Miscellaneous#[,-c(2:3, 4)]
# Out:
#   Day percent_active
# 1 NaN 8.2854

# %%
# 13th March ---> day 52
dNo = 59    # get the day no. to pridict

test_Miscellaneous$'Day' = dNo

# %% [markdown]
# <br />
# 1. #### By Linear Model

# %%
# modeling variable  --->  fit
Prediction = cbind(
                test_Miscellaneous[,c("Day", "percent_active")],
                percent_pridicted = predict(fit.lm, test_Miscellaneous)
             )
Prediction
# Out:
#   Day percent_active percent_pridicted
# 1 59  8.2854         58.44957

# %% [markdown]
# <br />
# 2. #### By Polynomial Model

# %%
# modeling variable  --->  model
Prediction = cbind(
                test_Miscellaneous[,c("Day", "percent_active")],
                percent_pridicted = predict(model, test_Miscellaneous)
             )
Prediction
# Out:
# Warning message in predict.lm(model, test_Miscellaneous):
# “prediction from a rank-deficient fit may be misleading”
#   Day percent_active percent_pridicted
# 1 59  8.2854         8.323115

# %% [markdown]
# <br />
# 3. #### By SVMK Model

# %%
# modeling variable  --->  model
Prediction = cbind(
                test_Miscellaneous[,c("Day", "percent_active")],
                percent_pridicted = predict(fit.svmk, test_Miscellaneous)
             )
Prediction
# Out:
#   Day percent_active percent_pridicted
# 1 59  8.2854         13.62037

# %% [markdown]
# <br />
# 3. #### By KNN Model

# %%
# modeling variable  --->  model
Prediction = cbind(
                test_Miscellaneous[,c("Day", "percent_active")],
                percent_pridicted = predict(fit.knn, as.matrix(test_Miscellaneous[,1]))
             )
Prediction[]
# Out:
#   Day percent_active percent_pridicted
# 1 59  8.2854         9.122076

# %% [markdown]
# <hr /> <br />

# %%
# world on day 58
# 92.63192 ---> @deg = 16
# 88.90763 ---> @deg = 19
