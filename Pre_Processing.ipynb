# %% [markdown]
# <a href="https://colab.research.google.com/github/ravi-prakash1907/A-tracking-of-COVID-19/blob/master/Pre_Processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Pre-processing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import math
from statistics import mean

# %%
dfURL = "https://raw.githubusercontent.com/ravi-prakash1907/kba-research-work/main/Dataset/papersData.csv?token=GHSAT0AAAAAABRJ7LRBUYBRA3L4KUJWNLFIYQOGD3Q"
df = pd.read_csv(dfURL)
df.head()
# Out:
#                scopus_id  ...                                                url
# 0  SCOPUS_ID:85120480314  ...  https://www.scopus.com/inward/record.uri?partn...
# 1  SCOPUS_ID:85122297088  ...  https://www.scopus.com/inward/record.uri?partn...
# 2  SCOPUS_ID:85123032759  ...  https://www.scopus.com/inward/record.uri?partn...
# 3  SCOPUS_ID:85119452980  ...  https://www.scopus.com/inward/record.uri?partn...
# 4  SCOPUS_ID:85112637643  ...  https://www.scopus.com/inward/record.uri?partn...
#
# [5 rows x 10 columns]

# %%
df.shape
# Out:
# (25, 10)

# %%
df.describe()
# Out:
#                     scopus_id  ...                                                url
# count                      25  ...                                                 25
# unique                     25  ...                                                 25
# top     SCOPUS_ID:85120480314  ...  https://www.scopus.com/inward/record.uri?partn...
# freq                        1  ...                                                  1
#
# [4 rows x 10 columns]

# %%
df.dtypes
# Out:
# scopus_id       object
# cover_date      object
# title           object
# sub_type        object
# first_author    object
# publication     object
# type            object
# country         object
# doi             object
# url             object
# dtype: object
